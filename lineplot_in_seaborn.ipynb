# %% [markdown]
# # 1. What is a Line Plot in Seaborn?
# 🔹 A line plot connects data points with straight lines.
#
# It shows how a numeric variable changes over another variable, typically over time.
#
# It's ideal for trend analysis.
#
#
# # 2. Why Do We Use It?
# <table>
#     <tr>
#         <td>Purpose</td>
#         <td>Explanation</td>
#     </tr>
#     <tr>
#         <td>Track trends</td>
#         <td>Shows how a variable (like sales, temperature, etc.) changes over time</td>
#     </tr>
#     <tr>
#         <td>Compare groups</td>
#         <td>You can compare multiple lines using hue= (e.g., sales by branch)</td>
#     </tr>
#     <tr>
#         <td>Visualize patterns</td>
#         <td>Helps detect seasonality, growth, or decline</td>
#     </tr>
#     <tr>
#         <td><b>Ideal for time-series</b></td>
#         <td><b>Most useful when your x-axis is a time-based variable</b></td>
#     </tr>
#     <tr>
#         <td>Spot fluctuations</td>
#         <td>Makes spikes, drops, or changes in patterns easy to see</td>
#     </tr>
# </table>

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load dataset
file_path = r"D:\DataVisualizationForPython\datasets\orders.xlsx"

file = pd.read_excel(file_path)

if file is None:
    raise FileNotFoundError("File Path Not Found. Please, Check Your File Path")

df = pd.DataFrame(file)
df.head()
# Out:
#   Item_ID     Item_W              Item_Type    Item_MRP Outlet_ID  \
# 0   FDN27   9.437510            Snack Foods  195.313244    OUT046
# 1   FDW35   9.033762  Fruits and Vegetables   36.371449    OUT035
# 2   FDS28  20.884849           Frozen Foods   70.318167    OUT013
# 3   FDC09  19.976300            Snack Foods  121.723264    OUT018
# 4   FDX04  10.824812            Snack Foods  264.673302    OUT035
#
#    Outlet_Year Outlet_Size Outlet_Location_Type        Sales  Tier
# 0         1997       Small               Tier 1   897.085562     1
# 1         2003       Small               Tier 2  1639.303513     2
# 2         2008       Small               Tier 1  2664.773737     1
# 3         2009      Medium               Tier 3   440.859593     3
# 4         2004       Small               Tier 1    29.807098     1

# %%
# Basic line plot
plt.figure(figsize = (8,6))
sns.lineplot(data = df, x = "Outlet_Year", y ="Sales", ci = None)
plt.xlabel("Year")
plt.ylabel("Total Sales")
plt.tight_layout()
#plt.xticks(np.arange(0,df["Sales"].max()))
plt.show()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_5272\247929995.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data = df, x = "Outlet_Year", y ="Sales", ci = None)

# %%
plt.figure(figsize = (8,6))
sns.lineplot(data = df, x = "Outlet_Year", y ="Sales", ci = None, estimator="sum", color = "darkgray")
plt.xlabel("Year")
plt.ylabel("Sum of Sales")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_5272\318104583.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data = df, x = "Outlet_Year", y ="Sales", ci = None, estimator="sum", color = "darkgray")

# %%
age = np.arange(20, 60, 10)
frequency = age + 15
print(age)
print(frequency)

plt.figure(figsize=(6,4))
sns.lineplot(x = age, y = frequency, color = "yellow", marker = "o")
plt.title("Linear Plot of Age Frequencies")
plt.xlabel("Age")
plt.ylabel("Frequency")
# plt.grid(True, linestyle='--', alpha=0.6)
plt.xticks(ticks = age)
plt.tight_layout()
plt.show()
# Out:
# [20 30 40 50]
# [35 45 55 65]

# %%
# create years
years = np.arange(2000, 2025, 1)
print(years)

# create sales
sales = np.random.normal(600, 24, 100).reshape(25,4) # mean, std, sample

# convert float to int
int_sales = np.round(sales, 0).astype(int)
print(int_sales)

df = pd.DataFrame(int_sales, columns=["Q1", "Q2", "Q3", "Q4"])
df["Year"] = years
df.head()
# Out:
# [2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013
#  2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024]
# [[608 606 623 577]
#  [609 583 574 625]
#  [627 650 618 610]
#  [591 626 613 584]
#  [587 582 532 618]
#  [584 601 608 604]
#  [622 632 584 578]
#  [629 596 567 599]
#  [569 639 602 585]
#  [587 640 586 563]
#  [622 572 569 606]
#  [601 566 631 648]
#  [587 608 587 643]
#  [622 616 612 593]
#  [576 666 617 617]
#  [602 582 642 551]
#  [574 580 618 596]
#  [558 626 597 606]
#  [626 581 604 614]
#  [583 574 604 569]
#  [602 605 616 632]
#  [594 599 621 602]
#  [602 569 578 599]
#  [617 588 546 623]
#  [611 580 614 623]]
#     Q1   Q2   Q3   Q4  Year
# 0  608  606  623  577  2000
# 1  609  583  574  625  2001
# 2  627  650  618  610  2002
# 3  591  626  613  584  2003
# 4  587  582  532  618  2004

# %%
df.groupby(by = "Year")[["Q1","Q3"]].agg(
    {
    "Q1": ["sum","mean"],
    "Q3":["sum","mean"]
    }
)

# %%
sns.lineplot(data = df, x = "Year", y = "Q1", ci = None, palette = "Paired_r")
plt.title("Line Plot of Q1 Per Each Year")
plt.xlabel("Year")
plt.ylabel("Q1")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_5272\3018254414.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data = df, x = "Year", y = "Q1", ci = None, palette = "Paired_r")
# C:\Users\Asus\AppData\Local\Temp\ipykernel_5272\3018254414.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data = df, x = "Year", y = "Q1", ci = None, palette = "Paired_r")

# %%
sns.lineplot(data = df, x = "Year", y = "Q2", ci = None, color = "red")
plt.title("Line Plot of Q2 Per Each Year")
plt.xlabel("Year")
plt.ylabel("Q2")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_5272\3268862113.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data = df, x = "Year", y = "Q2", ci = None, color = "red")

# %%
# use subplot
fig, axes = plt.subplots(2, 2, figsize=(18, 12))
fig.suptitle('Quantiles Stats by Year')
sns.lineplot(ax=axes[0, 0], data=df, x= 'Year', y='Q1', color = "green")
sns.lineplot(ax=axes[0, 1], data=df, x= 'Year', y='Q2', color = "blue")
sns.lineplot(ax=axes[1, 0], data=df, x='Year', y='Q3', color = "yellow")
sns.lineplot(ax=axes[1, 1], data=df, x='Year', y='Q4', color = "black")
# Out:
# <Axes: xlabel='Year', ylabel='Q4'>
