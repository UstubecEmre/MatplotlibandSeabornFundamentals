# %% [markdown]
# # 1. Chart Types Used in Matplotlib
# 📊 1. Line Plot (plt.plot)
#
# Use case: Trends over time or continuous data.
#
# >> Example: Stock prices over days.
#
# >>> plt.plot(x, y)
#
# 📈 2. Bar Chart (plt.bar)
#
# Use case: Comparing categories.
#
# >> Example: Population by country.
#
# >>> plt.bar(categories, values)
#
# 📉 3. Horizontal Bar Chart (plt.barh)
#
# Use case: Same as bar chart, but horizontal.
#
# Useful for: Long category names.
#
# >>> plt.barh(categories, values)
#
#
# 📦 4. Histogram (plt.hist)
#
# Use case: Distribution of a single numerical variable.
#
# >> Example: Distribution of student grades.
#
# >>> plt.hist(data, bins=10)
#
# 🔵 5. Scatter Plot (plt.scatter)
#
# Use case: Relationship between two numeric variables.
#
# >> Example: Height vs. weight.
#
# >>> plt.scatter(x, y)
#
#
# 🍩 6. Pie Chart (plt.pie)
#
# Use case: Proportions or percentages.
#
# >> Example: Market share by company.
#
# >>> plt.pie(sizes, labels=labels)
#
#
# 🧩 7. Box Plot (plt.boxplot)
#
# Use case: Summary of distribution (median, quartiles, outliers).
#
# >> Example: Comparing test scores between groups.
#
# >>> plt.boxplot(data)
#
#
# 🧪 8. Area Chart
#
# Use case: Like line chart, but with filled area under the curve.
#
# >>> plt.fill_between(x, y)
#
#
# 🧭 9. Stack Plot (plt.stackplot)
#
# Use case: Trends over time across multiple categories.
#
# >> Example: Time spent on activities over a week.
#
# >>> plt.stackplot(x, y1, y2, y3)
#
#
# 🔳 10. Heatmap (via imshow or seaborn)
#
# Use case: Visualizing 2D matrix or correlations.
#
# Note: Often created with Seaborn (sns.heatmap()), but also possible with:
#
# >>> plt.imshow(matrix, cmap='hot', interpolation='nearest')

# %% [markdown]
# ✅ Summary:
#
# o Use bar, pie, and count plots for categorical data.
#
# o Use line, scatter, histogram, and box plots for numerical data.

# %%
# import libraries
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create dataset
year = [1999, 2000, 2001, 2002]
apple_price = [2, 2.25, 2.5, 3.5]
banana_price = [3.25, 4, 4.25, 5]
watermelon_price = [5.5, 6.27, 7.5, 9]


# Stack Plot
plt.plot([],[], color = 'black', label = "apple_price")
plt.plot([],[], color = 'darkblue', label = "banan_price")
plt.plot([],[], color = 'darkred', label = "watermelon_price")

plt.stackplot(year, apple_price, banana_price, watermelon_price, colors = ["black","darkblue","darkred"])
plt.title("Fruit Price By Years")
plt.xlabel("Year")
plt.ylabel("Price")
plt.legend()
plt.show()

# %%
# Pie Chart
sales_channel = ['Grocery',"Greengrocer", "Vegetable Market"]

number_of_sales = [130, 175, 380]
colors = ['orange', 'teal', 'blueviolet']

plt.pie(number_of_sales, labels = sales_channel, colors= colors, shadow= True, explode = (0.02, 0.02, 0.02), autopct="%1.2f%%")
plt.show()

# %%
#Bar Chart

# first list = working hours, second list = received grade 
# set the width 
seasons = np.arange(1,9)
plt.bar([1, 1, 1.5, 2.5, 1.5, 3, 4, 2], [45, 60, 70, 60, 55, 80, 82, 75], label = "student1",  width = 0.3, color = "rosybrown")
plt.bar([1, 1.5, 2, 2.25, 3.5, 3, 4.5, 3], [65, 80, 72, 78, 85, 95, 88, 96], label = "student2",width =  0.3, color = "firebrick")
plt.legend()
plt.xlabel("Working Hours")
plt.ylabel("Received Grade")
plt.title("Student Info")
plt.tight_layout()
plt.show()

# %%
# Define categories (e.g., Exam numbers or Hour blocks)
categories = np.arange(8) # 0, 1, 2, 3, 4, 5, 6, 7

# Student grades
student1_grades = [45, 60, 70, 60, 55, 80, 82, 75]
student2_grades = [65, 80, 72, 78, 85, 95, 88, 96]

# Bar width
width = 0.35

# Plot bars side by side
plt.bar(categories - width/2, student1_grades, width=width, label="Student 1", color="#0C5209")
plt.bar(categories + width/2, student2_grades, width=width, label="Student 2", color="#6BE289")

# Add labels, title, legend
plt.xlabel("Sessions / Hour Blocks")
plt.ylabel("Received Grade")
plt.title("Student Performance Based on Working Hours")
plt.xticks(categories, [f"Session {i+1} " for i in categories])
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.8)

# Show plot
plt.tight_layout()
plt.show()

# %%
# Histogram
temperatures = [-10, -17, -12, -8, -9, 12, 14, 45, 52, 32, 30, 28, 29, 28, 28, 27, 14, 16, -3, 3, 10, 20, 14, 25, 41, 36, 54, 3, 12, -23, -6, -1, 0, 18, 19, 22, 14, 23]
temperatures_group = [-30, -20, -10, 0, 10, 20, 30, 40, 50, 60]

# use hist()
plt.hist(x = temperatures,  bins = temperatures_group, histtype = 'bar', rwidth= 0.6, color="orange")
plt.xlabel("Temperatures")
plt.ylabel("Temperature Ranges")
plt.title("Example of Histogram Chart")
plt.show()

# %%
temp_list = np.random.randint(-20, 60, 50 )
print(temp_list)
temperatures_group = [-30, -20, -10, 0, 10, 20, 30, 40, 50, 60]


# use hist()
plt.hist(x = temp_list,  bins = temperatures_group, histtype = 'stepfilled', rwidth= 0.6, color="olive")
plt.xlabel("Temperatures")
plt.ylabel("Temperature Ranges")
plt.title("Example Of Stepfilled Histtype")
plt.show()
# Out:
# [-11  55   1  18  57 -14  24 -10  29 -14  26 -16  37  16  47  27 -11  56
#   19 -17  49  24  13  32   0 -18  33  54   2  41  30  -6  13 -20  17  48
#  -11  -1   1  35  45  41  -2   9  55   8  17  45  15  31]
