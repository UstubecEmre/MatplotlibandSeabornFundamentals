# %% [markdown]
# # 1. What is Violinplot?
#
# A Violin Plot is a chart that shows the distribution of a numeric variable — similar to a box plot, but more detailed.
#
# It combines:
#
# A box plot (showing median, quartiles, etc.)
#
# A density plot (showing how values are spread out)
#
# 🟣 In Seaborn, it's created using sns.violinplot().
#
#
# ### 1.1. ✅ What It Looks Like
#
# A violin plot looks like a symmetrical shape (like a violin 🎻), which shows:
#
# Where the data is concentrated (fatter areas)
#
# Where the data is sparse (thinner areas)
#
# Median and quartile lines inside (just like a boxplot)
#
#
# # 2. Why We Use Violinplot?
# <table>
#     <tr>
#         <th>Reason</th>
#         <th>Beginner-Friendly Explanation</th>
#     </tr>
#     <tr>
#         <td>Show distribution</td>
#         <td>You can see where most data points are located</td>
#     </tr>
#      <tr>
#         <td>Compare groups</td>
#         <td>Compare how data spreads across categories (e.g., scores by gender)</td>
#     </tr>
#     <tr>
#         <td>See outliers & shape</td>
#         <td>Shows not just median and quartiles, but also the "shape" of the data.</td>
#     </tr>
#     <tr>
#         <td>More info than box plot</td>
#         <td>It includes density — which a boxplot alone doesn't show.</td>
#     </tr>
# </table>
#
#
#
#
# # 3. 📌 Summary (Beginner-Friendly)
# Violin Plot = Box Plot + Distribution Curve
#
# Great for:
#
# Seeing spread
#
# Spotting skewness (left/right bias)
#
# Comparing groups
#
# Created in Seaborn using sns.violinplot()

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load dataset and convert DataFrame
def load_dataset(df_name, file_path):
    file_path = file_path
    df_name = df_name
    
    df_name = pd.read_csv(file_path)
    if df_name is None:
        raise FileNotFoundError("File Path Not Found")
    
    df = pd.DataFrame(df_name)
    return df


df = load_dataset(file_path= r"D:\DataVisualizationForPython\datasets\supermarket_sales_utf8.csv",df_name = "sales")

# %%
# fix column names
def fix_column_names(dataframe):
    dataframe.columns = [col.lower().replace(" ", "_") for col in dataframe.columns]
    
# call the fix_column_names
fix_column_names(df)
df.head()
# Out:
#     invoice_id branch      city customer_type  gender            product_line  \
# 0  692-92-5582      B  Mandalay        Member  Female      Food_and_beverages
# 1  351-62-0822      B  Mandalay        Member  Female     Fashion_accessories
# 2  529-56-3974      B  Mandalay        Member    Male  Electronic_accessories
# 3  299-46-1805      B  Mandalay        Member  Female       Sports_and_travel
# 4  319-50-3348      B  Mandalay        Normal  Female      Home_and_lifestyle
#
#    unit_price  quantity  tax_5%    total                 date      time  \
# 0       54.84         3   8.226  172.746            2/20/2019  13:27:00
# 1       14.48         4   2.896   60.816  2019-06-02 00:00:00  18:07:00
# 2       25.51         4   5.102  107.142  2019-09-03 00:00:00  17:03:00
# 3       93.72         6  28.116  590.436            1/15/2019  16:19:00
# 4       40.30         2   4.030   84.630  2019-11-03 00:00:00  15:30:00
#
#        payment    cogs  gross_margin_percentage  gross_income  rating
# 0  Credit card  164.52                 4.761905         8.226     5.9
# 1      Ewallet   57.92                 4.761905         2.896     4.5
# 2         Cash  102.04                 4.761905         5.102     6.8
# 3         Cash  562.32                 4.761905        28.116     4.5
# 4      Ewallet   80.60                 4.761905         4.030     4.4

# %%
# Violinplot
plt.figure(figsize = (5, 3))
sns.violinplot(data = df, x = "quantity", color = "orange") # horizontal
plt.xlabel("Quantity")
plt.tight_layout()
plt.show()

# %%
# Example
sns.violinplot(data = df, x = "customer_type", y = "cogs" )
plt.title("Violinplot For Cogs Per Customer Type")
plt.tight_layout()
plt.show()

# %%
# two categorical and one numerical variable
sns.violinplot(data = df, x = "customer_type", hue = "branch", hue_order = ["A","B","C"], y = "cogs" )
plt.title("Violinplot For Cogs Per Customer Type")
plt.xlabel("Customer Type")
plt.ylabel("COGS")
plt.tight_layout()
plt.show()

# %%
# split and inner arguments
sns.violinplot(data = df, 
               x = "customer_type", 
               hue = "gender", 
               hue_order = ["Male","Female"], 
               y = "cogs", 
               split = True,
               inner = "quartile",
               palette="autumn")
plt.title("Violinplot For Cogs Per Customer Type")
plt.xlabel("Customer Type")
plt.ylabel("COGS")
plt.tight_layout()
plt.show()

# %%
# cut and band-width argument
plt.figure(figsize = (15, 10))
sns.violinplot(data = df, 
               x = "product_line", 
               hue = "gender", 
               hue_order = ["Male","Female"], 
               y = "cogs", 
               split = True,
               inner = "stick",
               palette="viridis",
               bw = 0.4,
               cut = 0)
plt.title("Violinplot For Cogs Per Product Line")
plt.xlabel("Product Line")
plt.ylabel("COGS")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_10444\2553478398.py:3: FutureWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method`/`bw_adjust`.
# Setting `bw_method=0.4`, but please see docs for the new parameters
# and update your code. This will become an error in seaborn v0.15.0.
#
#   sns.violinplot(data = df,
